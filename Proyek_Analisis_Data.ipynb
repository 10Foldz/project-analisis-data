# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Angga Aji Kurniawan
# - **Email:** anggaajik03@gmail.com
# - **ID Dicoding:** anggaaji

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana pengaruh cuaca terhadap jumlah sepeda yang disewa?
# - Apakah ada pola musiman dalam penggunaan sepeda, dan bagaimana distribusi pemakaian di hari kerja dan akhir pekan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# !pip install pipreqs

# %%
# !pip install streamlit

# %%
# !pip install --upgrade --force-reinstall numpy
# Out:
# ...
#   Using cached numpy-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.6.1 requires numpy<2.0a0,>=1.23, but you have numpy 2.1.1 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.1.1 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.1.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.1 which is incompatible.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pipreqs "/content/drive/MyDrive/Colab Notebooks/Proyek Analisis" --scan-notebooks --force
# Out:
# WARNING: Import named "numpy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "numpy" was resolved to "numpy:2.1.1" package (https://pypi.org/project/numpy/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "pandas" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pandas" was resolved to "pandas:2.2.3" package (https://pypi.org/project/pandas/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "seaborn" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "seaborn" was resolved to "seaborn:0.13.2" package (https://pypi.org/project/seaborn/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv('day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv('hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# Cek apakah ada nilai kolom yang kosong

# %%
print(day_df.isnull().sum())
print(hour_df.isnull().sum())
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Dataset memiliki kolom yang terdefinisi dengan baik

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai tabel `day_df`

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# #### Menilai tabel `hour_df`

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.nunique()
# Out:
# instant       17379
# dteday          731
# season            4
# yr                2
# mnth             12
# hr               24
# holiday           2
# weekday           7
# workingday        2
# weathersit        4
# temp             50
# atemp            65
# hum              89
# windspeed        30
# casual          322
# registered      776
# cnt             869
# dtype: int64

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - Tidak ada missing value maupun duplicate pada masing - masing tabel

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan tabel `day_df`

# %%
day_df_cleaned = day_df.drop(columns=['instant'])

# %% [markdown]
# #### Membersihkan tabel `hour_df`

# %%
hour_df_cleaned = hour_df.drop(columns=['instant'])

# %% [markdown]
# **Insight:**
# - Drop kolom 'instant' karena hanya sebagai index

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore `day_df` dan `hour_df`

# %%
day_df.sample(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 47        48  2011-02-17       1   0     2        0        4           1
# 529      530  2012-06-13       2   1     6        0        3           1
# 121      122  2011-05-02       2   0     5        0        1           1
# 546      547  2012-06-30       3   1     6        0        6           0
# 503      504  2012-05-18       2   1     5        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 47            1  0.435833  0.428658  0.505000   0.230104     259        2216
# 529           1  0.655833  0.611117  0.582083   0.343279    1173        6248
# 121           2  0.549167  0.532833  0.730000   0.183454     847        3554
# 546           1  0.765000  0.687508  0.601250   0.161071    1455        4232
# 503           1  0.564167  0.551121  0.523333   0.136817    1521        6118
#
#       cnt
# 47   2475
# 529  7421
# 121  4401
# 546  5687
# ...

# %%
hour_df.sample(5)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 7061      7062  2011-10-26       4   0    10  20        0        3
# 12014    12015  2012-05-20       2   1     5  19        0        0
# 9272      9273  2012-01-27       1   1     1   6        0        5
# 1297      1298  2011-02-27       1   0     2   6        0        0
# 3255      3256  2011-05-20       2   0     5  13        0        5
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 7061            1           1  0.50  0.4848  0.88     0.0000      27
# 12014           0           1  0.66  0.6212  0.61     0.4179     142
# 9272            1           2  0.42  0.4242  1.00     0.3284       0
# 1297            0           1  0.24  0.2879  0.87     0.0000       2
# 3255            1           3  0.60  0.6212  0.56     0.2836      60
#
#        registered  cnt
# 7061          180  207
# 12014         260  402
# 9272           72   72
# 1297            1    3
# 3255          172  232

# %%
day_df.describe(include="all")
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2011-01-01         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %%
hour_df.describe(include="all")
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-01-01           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %%
day_df['dteday'].is_unique
# Out:
# True

# %%
hour_df['dteday'].is_unique
# Out:
# False

# %%
day_season_group = day_df.groupby('season')['cnt'].mean()

# %%
hour_weekday_group = hour_df.groupby('weekday')['cnt'].mean()

# %%
day_df['weathersit'].value_counts()
# Out:
# weathersit
# 1    463
# 2    247
# 3     21
# Name: count, dtype: int64

# %%
hour_df['weathersit'].value_counts()
# Out:
# weathersit
# 1    11413
# 2     4544
# 3     1419
# 4        3
# Name: count, dtype: int64

# %% [markdown]
# #### Visualisasi `average bike rentals` by `weather`

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='weathersit', y='cnt', data=day_df, estimator=np.mean)
plt.title('Average Total Bike Rentals by Weather Situation (Day)')
plt.xlabel('Weather Situation')
plt.ylabel('Average Total Rentals')
plt.show()

# %% [markdown]
# #### Visualisasi `total bike rentals distribution` by `season`

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='season', y='cnt', data=day_df)
plt.title('Total Bike Rentals Distribution by Season (Day)')
plt.xlabel('Season')
plt.ylabel('Total Rentals')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# **Insight:**
# - Statistik dan analisis visual mengenai hubungan `weather`, `season`, dan `bike rentals`

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana pengaruh cuaca terhadap jumlah sepeda yang disewa?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='weathersit', y='cnt', data=day_df)
plt.title('Impact of Weather on Total Bike Rentals (Day)')
plt.xlabel('Weather Situation')
plt.ylabel('Total Rentals')
plt.xticks([0, 1, 2, 3], ['Clear/Few Clouds', 'Mist/Cloudy', 'Light Snow/Rain', 'Heavy Rain/Snow'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ### Pertanyaan 2: Apakah ada pola musiman dalam penggunaan sepeda, dan bagaimana distribusi pemakaian di hari kerja dan akhir pekan?

# %% [markdown]
# #### Pola Musiman Pemakaian Sepeda

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='mnth', y='cnt', hue='season', style='season', markers=True, dashes=False, data=day_df_cleaned, palette='tab10')
plt.title('Pola Musiman Pemakaian Sepeda (Day)')
plt.xlabel('Month')
plt.ylabel('Total Rentals')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Season', loc='upper left', labels=['Spring', 'Summer', 'Fall', 'Winter'])
plt.show()

# %% [markdown]
# **Insight:**
# - Cuaca buruk (kategori 3 dan 4) mengurangi `bike rentals` secara signifikan

# %% [markdown]
# #### Distribusi Pemakaian di Hari Kerja dan Akhir Pekan

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='workingday', y='cnt', data=day_df_cleaned)
plt.title('Distribusi Pemakaian Sepeda di Hari Kerja dan Akhir Pekan (Day)')
plt.xlabel('Working Day (1: Hari Kerja, 0: Akhir Pekan)')
plt.ylabel('Total Rentals')
plt.xticks([0, 1], ['Akhir Pekan', 'Hari Kerja'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# **Insight:**
# - Jika dilihat dari median dan rentang distribusi, pemakaian sepeda di hari kerja cenderung lebih tinggi dibandingkan akhir pekan.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1
# Cuaca buruk secara signifikan mengurangi jumlah penyewaan sepeda.
#
# - Conclusion pertanyaan 2
# Terdapat pola musiman yang jelas, dengan harga sewa yang lebih tinggi selama musim panas dan musim gugur.
